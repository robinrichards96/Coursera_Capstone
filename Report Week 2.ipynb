# %% [markdown]
# # Coursera Capstone Project

# %% [markdown]
# ### Introduction and Business Problem

# %% [markdown]
# This project will determine the best location for a new shopping centre in London using data from a variety of sources and machine learning techniques.
#
# Land prices in London are well known for being extremely high, the scarcity of land coupled with high demand means that building anywhere in the capital is expensive. It's therefore important that anyone wishing to develop commercially on land in London is adequately equipped with the right data and the right analysis.
#
# The aim of this project is to use data from the Foursquare API as well as population data scraped from online sources to determine where the most effective location to build a new shopping centre in London is.

# %% [markdown]
# ### Target Audience¶

# %% [markdown]
# The target audience for this project is property developers that might be looking to invest in a new shopping centre in London and don't have sufficient analytics to determine where the best location is. The Westfield shopping centre in Shepherds Bush cost £1.7 billion to construct, this shows the scale of the investments that companies are willing to put into these projects. It is therefore paramount that they have sufficient data and projections to base these investments on.

# %% [markdown]
# ### Description of the Data¶

# %% [markdown]
# To carry out this analysis, I will use the Foursquare API to generate a dataset of the existing locations of shopping centres across different London boroughs. I plan to use this data to determine which borough has the fewest number of shopping centres, using the assumption that developers don't want to build an area that's already saturated.
#
# Once I've determined this, I will then scrape data from 'https://www.citypopulation.de/en/uk/greaterlondon/' on the population of each London borough, this will allow me to calculate which boroughs have the largest population to the smallest number of shopping centres. This will form the basis for my recommendations.
#
# I will also need to get locational data on each of the London boroughs, to do this I will scrape the webpage 'https://en.wikipedia.org/wiki/List_of_London_boroughs' to get the latitude and longitude.

# %% [markdown]
# ### Methodology

# %% [markdown]
# The first analysis that I did for this project was to generate a dataframe with the population growth rates for each of the London boroughs, the results of which are shown below:
# ![image.png](attachment:image.png)

# %% [markdown]
# Once I had this information, I then needed to add in the latitude and longitude for the boroughs, after scraping this information I could join it to the dataframe:
# ![image.png](attachment:image.png)

# %% [markdown]
# Once I had this data, I was able to start exploring the Foursquare API to find out how many shopping centres currently exist in each borough. I was able to pull in all of the Foursquare venues within a each of the boroughs.

# %% [markdown]
# Below shows the number of venues I was able to find for each borough.
# ![image.png](attachment:image.png)

# %% [markdown]
# After filtering the venues by those that fell into the category 'shopping mall', I was able to use K means clustering to sort each borough into 3 clusters depending on how many shopping centres each had.

# %% [markdown]
# ### Results

# %% [markdown]
# After carrying out a K means clustering algorithm on the data, I was able to determine which of 3 clusters each borough fell into, the results are shown below.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# I then plotted these clusters on a map of London using Folium to visually display the results.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# On this map, the green colours signify cluster 2, the purple colours signify cluster 1 and the red colours signify cluster 0. As we can see, the map is mostly red which means that there were a lot of boroughs that do not contain shopping centres.

# %% [markdown]
# After plotting the results visually, I compared them back to the data on population growth on each of the boroughs. I filtered all the boroughs that were in cluster 0 and ranked them by their population growth rate over the past 20 years. Of those boroughs, the one with the highest population growth rate is Newham. I would therefore recommend that  new shopping centre be built in Newham.
# ![image.png](attachment:image.png)
